# %%
from ultralytics import YOLO
from ultralytics import settings

# %%
# Update a setting
settings.update({"datasets_dir": "/home/sha/Documents/robohand/funetune/YOLO_dataset"})
settings.update({"weights_dir": "/home/sha/Documents/robohand/funetune/weights"})
settings.update({"runs_dir": "/home/sha/Documents/robohand/funetune/runs"})
print(settings)
# Out:
# JSONDict("/home/sha/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/home/sha/Documents/robohand/funetune/YOLO_dataset",
#   "weights_dir": "/home/sha/Documents/robohand/funetune/weights",
#   "runs_dir": "/home/sha/Documents/robohand/funetune/runs",
#   "uuid": "9fda4e3a8ab209a2175821e2a54ca138eabd2a77554cc6b3af608b6a7d8b24ee",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true
# }

# %%
model = YOLO("yolo11l.pt")
results = model.train(
    data="/home/sha/Documents/robohand/funetune/YOLO_dataset/data.yaml",
    epochs=200,
    imgsz=640,
    batch=16,
    device=0,
)
# Out:
# Ultralytics 8.3.110 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4070, 11886MiB)
# ...
